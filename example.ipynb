# %%
# Reading a CSV with progress bar
df = tpd.read_csv("large_file.csv")

# Custom description
df = tpd.read_csv("large_file.csv", desc="Loading my data")

# All pandas parameters still work
df = tpd.read_csv(
    "large_file.csv",
    sep="|",
    usecols=["col1", "col2"],
    parse_dates=["date_column"]
)

# Works with other pandas readers too
excel_df = tpd.read_excel("data.xlsx", sheet_name="Sheet1")
json_df = tpd.read_json("data.json")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 2
#       1 # Reading a CSV with progress bar
# ----> 2 df = tpd.read_csv("large_file.csv")
#       4 # Custom description
#       5 df = tpd.read_csv("large_file.csv", desc="Loading my data")
#
# NameError: name 'tpd' is not defined

# %%
import tqdm_pandas as tpd

# %%
import pandas as pd

# %%
pd.read_excel("Funds analysis.xlsx")
# Out:
#    Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0         NaN                                                NaN        NaN
# 1         NaN                                   Investment funds     Medium
# 2         NaN                          FTSE 100 Index Unit Trust        NaN
# 3         NaN        Emerging Markets Stock Index Fund (VANEMPA)        NaN
# 4         NaN                                 FTSE 100 UCITS ETF        NaN
# 5         NaN  FTSE All-World High Dividend Yield UCITS ETF (...        NaN
# 6         NaN                          Pension Retirement Funds         NaN
#
#         Unnamed: 3 Unnamed: 4  Unnamed: 5         Unnamed: 6 Unnamed: 7  \
# 0              NaN        NaN         NaN                NaN        NaN
# 1  Active/ Passive     Notes   Investment  Growth (expected)      Risk
# 2              NaN        NaN         NaN                NaN        NaN
# ...

# %%
tpd.read_excel("large_data.xlsx", sheet_name = 'Text_Data')
# Out:
# Reading Excel: 100%|██████████| 100/100 [00:05<00:00, 18.12%/s]
#            ID             Name  \
# 0           1  YCLzuBNBXgfGnRG
# 1           2  nvpAVnldiQKKKoh
# 2           3  xPkPKjEiNxpMZTA
# 3           4  vaoiQVaYOpJZuiA
# 4           5  wSBCbBJUjcKpFJE
# ...       ...              ...
# 99995   99996  oMxegmthUnymCYI
# 99996   99997  sgPFBrnOlAijmPo
# 99997   99998  QtjRIaiFNWSTmCD
# 99998   99999  HgUBMlUpDpQevUw
# 99999  100000  VCaOKmvwczWZpsS
#
#                                              Description Category SubCategory  \
# 0      InpOPEITQDmQMQBlyexNdPpqxpHyeGiTOgAGHqfPQDalXL...        A          Y2
# 1      MqEPyNdpVAFkhqVuzfkacOuFUdthpRIfNRVEYLMoGYSLpW...        C          X2
# 2      pJQBNvvLltcQmiMPWcRSMYBLwfZJuaKEfZZNJTVmIWlIop...        C          Y2
# 3      bgHvDpxtRuNsKtfPnGOJnSvLaHJkEKdmYCwCTBOlZFyYfH...        C          X1
# 4      wAeHNYbqjRzkKkjPMYbMoERuVGpREqiGvJsbnVEXlAzbEz...        E          X1
# ...
